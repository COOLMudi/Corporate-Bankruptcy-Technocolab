# %% [markdown]
# # Importing Data
#
# ---

# %%
! git clone https://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@github.com/COOLMudi/CORPORATE-BANKRUPTCY-PREDICTION.git
# Out:
# fatal: destination path 'CORPORATE-BANKRUPTCY-PREDICTION' already exists and is not an empty directory.

# %%
#Import the Libraries
from scipy.io import arff
import pandas as pd

#Load the data using "arff.loadarff" then convert it to dataframe
data = arff.loadarff('/content/CORPORATE-BANKRUPTCY-PREDICTION/data/2year.arff')
df = pd.DataFrame(data[0])

# %% [markdown]
# # Import the Libraries
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Inspection and organizing the data
#
#
# *   convert the types of the cplumns for the features to float
# *   convert class label types to int
#
#
# ---

# %%
df.head(10)
# Out:
#       Attr1    Attr2     Attr3     Attr4  ...    Attr62     Attr63   Attr64  class
# 0  0.202350  0.46500  0.240380    1.5171  ...  107.7400    3.38790   5.3440   b'0'
# 1  0.030073  0.59563  0.186680    1.3382  ...  622.6600    0.58619   1.2381   b'0'
# 2  0.257860  0.29949  0.665190    3.2211  ...   65.2150    5.59690  47.4660   b'0'
# 3  0.227160  0.67850  0.042784    1.0828  ...  142.4600    2.56210   3.0066   b'0'
# 4  0.085443  0.38039  0.359230    1.9444  ...   89.0580    4.09840   5.9874   b'0'
# 5  0.287840  0.55225  0.316340    1.7033  ...  110.8300    3.29330   6.3346   b'0'
# 6  0.153820  0.47248  0.311790    1.6898  ...  109.6400    3.32910   6.3692   b'0'
# 7  0.262520  0.45834  0.417040    1.9406  ...   74.0550    4.92880  15.6580   b'0'
# 8  0.079147  0.02240  0.897050  283.1200  ...    1.8823  193.91000   6.1798   b'0'
# 9  0.009901  0.71174  0.065186    1.1485  ...  136.5400    2.67320   2.3680   b'0'
#
# [10 rows x 65 columns]

# %%
data_keys= list(df.keys())
len(data_keys)
# Out:
# 65

# %%
print(df.shape)
# Out:
# (10173, 65)

# %%
df.describe().transpose()
# Out:
#           count        mean           std  ...        50%         75%           max
# Attr1   10172.0    0.043074      1.112028  ...   0.049493    0.141105  7.372700e+00
# Attr2   10172.0    0.646960      6.615405  ...   0.487335    0.705040  4.809600e+02
# Attr3   10172.0    0.070861      6.606495  ...   0.189695    0.400400  5.502200e+00
# Attr4   10151.0    4.144058     51.715242  ...   1.524400    2.741100  4.881600e+03
# Attr5   10149.0 -144.830797   7811.976260  ...  -1.907500   51.443000  7.068600e+04
# ...         ...         ...           ...  ...        ...         ...           ...
# Attr60   9630.0  375.332514  12294.315980  ...  10.353500   22.163500  6.399400e+05
# Attr61  10157.0   16.884020    295.762312  ...   6.988600   11.073000  2.686200e+04
# Attr62  10110.0  891.079947  43661.334983  ...  69.645500  116.320000  4.144800e+06
# Attr63  10151.0   11.217653    233.919213  ...   5.198900    9.012550  2.345400e+04
# Attr64   9961.0   55.275877   1526.588333  ...   4.536000   10.604000  1.276800e+05
#
# [64 rows x 8 columns]

# %%
df.corr()
# Out:
#            Attr1     Attr2     Attr3  ...    Attr62    Attr63    Attr64
# Attr1   1.000000 -0.429079  0.428541  ... -0.001080  0.008546 -0.104515
# Attr2  -0.429079  1.000000 -0.998605  ...  0.195149 -0.002190 -0.002082
# Attr3   0.428541 -0.998605  1.000000  ... -0.195482  0.002438  0.005369
# Attr4   0.002925 -0.005200  0.006087  ... -0.003101  0.015307 -0.000568
# Attr5   0.230805 -0.426259  0.427277  ... -0.069180  0.001075  0.000554
# ...          ...       ...       ...  ...       ...       ...       ...
# Attr60  0.006782 -0.001273  0.001327  ... -0.000795  0.522968  0.242183
# Attr61  0.002783  0.000863 -0.001734  ... -0.001066  0.411375  0.348528
# Attr62 -0.001080  0.195149 -0.195482  ...  1.000000 -0.000946 -0.000617
# Attr63  0.008546 -0.002190  0.002438  ... -0.000946  1.000000  0.842382
# Attr64 -0.104515 -0.002082  0.005369  ... -0.000617  0.842382  1.000000
#
# [64 rows x 64 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10173 entries, 0 to 10172
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   10172 non-null  float64
#  1   Attr2   10172 non-null  float64
#  2   Attr3   10172 non-null  float64
#  3   Attr4   10151 non-null  float64
#  4   Attr5   10149 non-null  float64
#  5   Attr6   10172 non-null  float64
#  6   Attr7   10172 non-null  float64
#  7   Attr8   10155 non-null  float64
#  8   Attr9   10169 non-null  float64
#  9   Attr10  10172 non-null  float64
#  10  Attr11  10172 non-null  float64
#  11  Attr12  10151 non-null  float64
#  12  Attr13  10110 non-null  float64
#  13  Attr14  10172 non-null  float64
#  14  Attr15  10161 non-null  float64
#  15  Attr16  10154 non-null  float64
#  16  Attr17  10155 non-null  float64
#  17  Attr18  10172 non-null  float64
#  18  Attr19  10109 non-null  float64
#  19  Attr20  10110 non-null  float64
#  20  Attr21  7009 non-null   float64
#  21  Attr22  10172 non-null  float64
#  22  Attr23  10110 non-null  float64
#  23  Attr24  9948 non-null   float64
#  24  Attr25  10172 non-null  float64
#  25  Attr26  10154 non-null  float64
#  26  Attr27  9467 non-null   float64
#  27  Attr28  9961 non-null   float64
#  28  Attr29  10172 non-null  float64
#  29  Attr30  10110 non-null  float64
#  30  Attr31  10110 non-null  float64
#  31  Attr32  10086 non-null  float64
#  32  Attr33  10151 non-null  float64
#  33  Attr34  10155 non-null  float64
#  34  Attr35  10172 non-null  float64
#  35  Attr36  10172 non-null  float64
#  36  Attr37  5655 non-null   float64
#  37  Attr38  10172 non-null  float64
#  38  Attr39  10110 non-null  float64
#  39  Attr40  10151 non-null  float64
#  40  Attr41  9976 non-null   float64
#  41  Attr42  10110 non-null  float64
#  42  Attr43  10110 non-null  float64
#  43  Attr44  10110 non-null  float64
#  44  Attr45  9632 non-null   float64
#  45  Attr46  10151 non-null  float64
#  46  Attr47  10099 non-null  float64
#  47  Attr48  10171 non-null  float64
#  48  Attr49  10110 non-null  float64
#  49  Attr50  10155 non-null  float64
#  50  Attr51  10172 non-null  float64
#  51  Attr52  10099 non-null  float64
#  52  Attr53  9961 non-null   float64
#  53  Attr54  9961 non-null   float64
#  54  Attr55  10172 non-null  float64
#  55  Attr56  10110 non-null  float64
#  56  Attr57  10171 non-null  float64
#  57  Attr58  10134 non-null  float64
#  58  Attr59  10171 non-null  float64
#  59  Attr60  9630 non-null   float64
#  60  Attr61  10157 non-null  float64
#  61  Attr62  10110 non-null  float64
#  62  Attr63  10151 non-null  float64
#  63  Attr64  9961 non-null   float64
#  64  class   10173 non-null  object
# dtypes: float64(64), object(1)
# memory usage: 5.0+ MB

# %%
df['class'].value_counts()
# Out:
# b'0'    9773
# b'1'     400
# Name: class, dtype: int64

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['class']= label_encoder.fit_transform(df['class'])

df['class'].unique()
# Out:
# array([0, 1])

# %%
df['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    9773
# 1     400
# Name: class, dtype: int64

# %% [markdown]
# # EDA
#
# ---
#
#
# Steps of Data Exploration and Preparation
#
# * Missing Value Treatment
# * Why missing value treatment is required ?
# * Why data has missing values?
# * Which are the methods to treat missing value ?
# * Techniques of Outlier Detection and Treatment
# * What is an outlier?
# * What are the types of outliers ?
# * What are the causes of outliers ?
# * What is the impact of outliers on dataset ?
# * How to detect outlier ?
# * How to remove outlier ?
# * The Art of Feature Engineering
# * What is Feature Engineering ?
# * What is the process of Feature Engineering ?
# * What is Variable Transformation ?
# * When should we use variable transformation ?
# * What are the common methods of variable transformation ?
# * What is feature variable creation and its benefits ?

# %% [markdown]
#   # Missing Value data analysis

# %%
total_cells= np.product(df.shape)
total_missing=df.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.8385016143789366

# %%
import missingno as msno
msno.matrix(df)

# %%
fig, axe = plt.subplots(figsize=(30,20))         
msno.heatmap(df,ax=axe)

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=df.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# **METHOD 1 knn Data Imputation -MISSING VALUE**
#
#
#
#
# ---

# %%
d1= df.copy()

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
for i in data_keys:
  X = np.array(d1[i]).reshape(-1,1)
  X_prep = imputer.fit_transform(X)
  d1[i] = X_prep.reshape(1,-1)[0]

d1.head()
# Out:
#       Attr1    Attr2     Attr3   Attr4  ...   Attr62   Attr63   Attr64  class
# 0  0.202350  0.46500  0.240380  1.5171  ...  107.740  3.38790   5.3440    0.0
# 1  0.030073  0.59563  0.186680  1.3382  ...  622.660  0.58619   1.2381    0.0
# 2  0.257860  0.29949  0.665190  3.2211  ...   65.215  5.59690  47.4660    0.0
# 3  0.227160  0.67850  0.042784  1.0828  ...  142.460  2.56210   3.0066    0.0
# 4  0.085443  0.38039  0.359230  1.9444  ...   89.058  4.09840   5.9874    0.0
#
# [5 rows x 65 columns]

# %%
total_cells= np.product(d1.shape)
total_missing=d1.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
d1.describe()
# Out:
#               Attr1        Attr2  ...         Attr64         class
# count  10173.000000  10173.00000  ...   10173.000000  10173.000000
# mean       0.043074      0.64696  ...      55.275877      0.039320
# std        1.111974      6.61508  ...    1510.596355      0.194364
# min      -75.331000      0.00000  ...  -10677.000000      0.000000
# 25%        0.000368      0.27771  ...       2.342400      0.000000
# 50%        0.049464      0.48734  ...       4.657300      0.000000
# 75%        0.141100      0.70503  ...      11.359000      0.000000
# max        7.372700    480.96000  ...  127680.000000      1.000000
#
# [8 rows x 65 columns]

# %% [markdown]
# ---

# %%
#!pip install impyute
#from impyute.imputation.cs import mice
#d2=df.copy()
# start the MICE training
#imputed_training=mice(d2.values.astype(float))

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# **There is imbalance in the Target value, we need to oversample it based**

# %% [markdown]
# # OverSamppling :SMOTE
#
# ---

# %%
from imblearn.over_sampling import SMOTE
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
sns.countplot(x=y)

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data 
data_x.shape
# Out:
#       Attr1    Attr2     Attr3   Attr4  ...   Attr61   Attr62   Attr63   Attr64
# 0  0.202350  0.46500  0.240380  1.5171  ...  5.16550  107.740  3.38790   5.3440
# 1  0.030073  0.59563  0.186680  1.3382  ...  0.63305  622.660  0.58619   1.2381
# 2  0.257860  0.29949  0.665190  3.2211  ...  3.19850   65.215  5.59690  47.4660
# 3  0.227160  0.67850  0.042784  1.0828  ...  5.06750  142.460  2.56210   3.0066
# 4  0.085443  0.38039  0.359230  1.9444  ...  4.00200   89.058  4.09840   5.9874
#
# [5 rows x 64 columns]
# (19546, 64)

# %%
df.head()
# Out:
#       Attr1    Attr2     Attr3   Attr4  ...   Attr62   Attr63   Attr64  class
# 0  0.202350  0.46500  0.240380  1.5171  ...  107.740  3.38790   5.3440      0
# 1  0.030073  0.59563  0.186680  1.3382  ...  622.660  0.58619   1.2381      0
# 2  0.257860  0.29949  0.665190  3.2211  ...   65.215  5.59690  47.4660      0
# 3  0.227160  0.67850  0.042784  1.0828  ...  142.460  2.56210   3.0066      0
# 4  0.085443  0.38039  0.359230  1.9444  ...   89.058  4.09840   5.9874      0
#
# [5 rows x 65 columns]
