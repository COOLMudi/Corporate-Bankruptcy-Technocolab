# %% [markdown]
# # Importing Data
#
# ---

# %%
! git clone https://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@github.com/COOLMudi/CORPORATE-BANKRUPTCY-PREDICTION.git
# Out:
# Cloning into 'CORPORATE-BANKRUPTCY-PREDICTION'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 38 (delta 8), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (38/38), done.

# %%
#Import the Libraries
from scipy.io import arff
import pandas as pd

#Load the data using "arff.loadarff" then convert it to dataframe
data = arff.loadarff('/content/CORPORATE-BANKRUPTCY-PREDICTION/data/5year.arff')
df = pd.DataFrame(data[0])

# %% [markdown]
# # Import the Libraries
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Inspection and organizing the data
#
#
# *   convert the types of the cplumns for the features to float
# *   convert class label types to int
#
#
# ---

# %%
df.head(10)
# Out:
#       Attr1    Attr2     Attr3   Attr4  ...   Attr62  Attr63    Attr64  class
# 0  0.088238  0.55472  0.011340  1.0205  ...  142.760  2.5568   3.25970   b'0'
# 1 -0.006202  0.48465  0.232980  1.5998  ...  111.140  3.2841   3.37000   b'0'
# 2  0.130240  0.22142  0.577510  3.6082  ...   71.531  5.1027   5.61880   b'0'
# 3 -0.089951  0.88700  0.269270  1.5222  ...  147.560  2.4735   5.92990   b'0'
# 4  0.048179  0.55041  0.107650  1.2437  ...  106.430  3.4294   3.36220   b'0'
# 5  0.231560  0.51047  0.472910  1.9393  ...  102.580  3.5581  75.94100   b'0'
# 6  0.099486  0.59991  0.374890  1.6529  ...  130.020  2.8072  31.64500   b'0'
# 7  0.078518  0.20546  0.103930  2.7939  ...   53.575  6.8129   0.47096   b'0'
# 8  0.125040  0.35440  0.314190  2.7127  ...   59.841  6.0995   2.22740   b'0'
# 9  0.293430  0.58649  0.083392  1.1694  ...  109.700  3.3273   3.85820   b'0'
#
# [10 rows x 65 columns]

# %%
data_keys= list(df.keys())
len(data_keys)
# Out:
# 65

# %%
print(df.shape)
# Out:
# (5910, 65)

# %%
df.describe().transpose()
# Out:
#          count        mean           std  ...       50%         75%          max
# Attr1   5907.0   -0.022347      6.163655  ...   0.04667    0.117050       87.459
# Attr2   5907.0    0.465086      5.751283  ...   0.45175    0.661635       72.416
# Attr3   5907.0    0.189155      1.177729  ...   0.21944    0.418430       28.336
# Attr4   5889.0    4.892476     91.434574  ...   1.65170    2.931000     6845.800
# Attr5   5899.0   19.406758  21529.322027  ...   0.49149   48.765000  1250100.000
# ...        ...         ...           ...  ...       ...         ...          ...
# Attr60  5642.0  911.033757  64154.692377  ...   9.03950   17.319500  4818700.000
# Attr61  5895.0   10.941497     41.166591  ...   6.19890    9.350900     1308.500
# Attr62  5910.0  241.978184   6221.135690  ...  73.77850  118.720000   451380.000
# Attr63  5889.0    9.127741    103.074304  ...   4.93000    8.115800     7641.300
# Attr64  5803.0   65.276716   2150.645860  ...   4.09830    9.204200   158180.000
#
# [64 rows x 8 columns]

# %%
df.corr()
# Out:
#            Attr1     Attr2     Attr3  ...    Attr62    Attr63    Attr64
# Attr1   1.000000 -0.192969  0.055964  ... -0.002093  0.006560 -0.173195
# Attr2  -0.192969  1.000000 -0.099898  ...  0.011984 -0.003677  0.001105
# Attr3   0.055964 -0.099898  1.000000  ... -0.065453  0.026308  0.002008
# Attr4   0.004478 -0.002658  0.023038  ... -0.001625  0.967649  0.001370
# Attr5   0.000262 -0.001782  0.006433  ... -0.045057  0.000568 -0.000337
# ...          ...       ...       ...  ...       ...       ...       ...
# Attr60  0.000254  0.000189 -0.000433  ... -0.000088 -0.006315 -0.000360
# Attr61  0.048275 -0.074895 -0.060067  ... -0.004104  0.005939 -0.002538
# Attr62 -0.002093  0.011984 -0.065453  ...  1.000000 -0.002883 -0.000844
# Attr63  0.006560 -0.003677  0.026308  ... -0.002883  1.000000  0.001672
# Attr64 -0.173195  0.001105  0.002008  ... -0.000844  0.001672  1.000000
#
# [64 rows x 64 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5910 entries, 0 to 5909
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   5907 non-null   float64
#  1   Attr2   5907 non-null   float64
#  2   Attr3   5907 non-null   float64
#  3   Attr4   5889 non-null   float64
#  4   Attr5   5899 non-null   float64
#  5   Attr6   5907 non-null   float64
#  6   Attr7   5907 non-null   float64
#  7   Attr8   5892 non-null   float64
#  8   Attr9   5909 non-null   float64
#  9   Attr10  5907 non-null   float64
#  10  Attr11  5907 non-null   float64
#  11  Attr12  5889 non-null   float64
#  12  Attr13  5910 non-null   float64
#  13  Attr14  5907 non-null   float64
#  14  Attr15  5904 non-null   float64
#  15  Attr16  5892 non-null   float64
#  16  Attr17  5892 non-null   float64
#  17  Attr18  5907 non-null   float64
#  18  Attr19  5910 non-null   float64
#  19  Attr20  5910 non-null   float64
#  20  Attr21  5807 non-null   float64
#  21  Attr22  5907 non-null   float64
#  22  Attr23  5910 non-null   float64
#  23  Attr24  5775 non-null   float64
#  24  Attr25  5907 non-null   float64
#  25  Attr26  5892 non-null   float64
#  26  Attr27  5519 non-null   float64
#  27  Attr28  5803 non-null   float64
#  28  Attr29  5907 non-null   float64
#  29  Attr30  5910 non-null   float64
#  30  Attr31  5910 non-null   float64
#  31  Attr32  5864 non-null   float64
#  32  Attr33  5889 non-null   float64
#  33  Attr34  5892 non-null   float64
#  34  Attr35  5907 non-null   float64
#  35  Attr36  5907 non-null   float64
#  36  Attr37  3362 non-null   float64
#  37  Attr38  5907 non-null   float64
#  38  Attr39  5910 non-null   float64
#  39  Attr40  5889 non-null   float64
#  40  Attr41  5826 non-null   float64
#  41  Attr42  5910 non-null   float64
#  42  Attr43  5910 non-null   float64
#  43  Attr44  5910 non-null   float64
#  44  Attr45  5642 non-null   float64
#  45  Attr46  5889 non-null   float64
#  46  Attr47  5875 non-null   float64
#  47  Attr48  5907 non-null   float64
#  48  Attr49  5910 non-null   float64
#  49  Attr50  5892 non-null   float64
#  50  Attr51  5907 non-null   float64
#  51  Attr52  5874 non-null   float64
#  52  Attr53  5803 non-null   float64
#  53  Attr54  5803 non-null   float64
#  54  Attr55  5910 non-null   float64
#  55  Attr56  5910 non-null   float64
#  56  Attr57  5907 non-null   float64
#  57  Attr58  5910 non-null   float64
#  58  Attr59  5907 non-null   float64
#  59  Attr60  5642 non-null   float64
#  60  Attr61  5895 non-null   float64
#  61  Attr62  5910 non-null   float64
#  62  Attr63  5889 non-null   float64
#  63  Attr64  5803 non-null   float64
#  64  class   5910 non-null   object
# dtypes: float64(64), object(1)
# memory usage: 2.9+ MB

# %%
df['class'].value_counts()
# Out:
# b'0'    5500
# b'1'     410
# Name: class, dtype: int64

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['class']= label_encoder.fit_transform(df['class'])

df['class'].unique()
# Out:
# array([0, 1])

# %%
df['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    5500
# 1     410
# Name: class, dtype: int64

# %% [markdown]
# # EDA
#
# ---
#
#
# Steps of Data Exploration and Preparation
#
# * Missing Value Treatment
# * Why missing value treatment is required ?
# * Why data has missing values?
# * Which are the methods to treat missing value ?
# * Techniques of Outlier Detection and Treatment
# * What is an outlier?
# * What are the types of outliers ?
# * What are the causes of outliers ?
# * What is the impact of outliers on dataset ?
# * How to detect outlier ?
# * How to remove outlier ?
# * The Art of Feature Engineering
# * What is Feature Engineering ?
# * What is the process of Feature Engineering ?
# * What is Variable Transformation ?
# * When should we use variable transformation ?
# * What are the common methods of variable transformation ?
# * What is feature variable creation and its benefits ?

# %% [markdown]
#   # Missing Value data analysis

# %%
total_cells= np.product(df.shape)
total_missing=df.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.2146297019393466

# %%
import missingno as msno
msno.matrix(df)

# %%
msno.heatmap(df)

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=df.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# **METHOD 1 Interpolation-MISSING VALUE**
#
# ---

# %%
d1= df.copy()

# %%
for i in data_keys:
  d1[i].interpolate(method='linear', direction = 'forward', inplace=True) 

d1.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4  ...   Attr62  Attr63  Attr64  class
# 0  0.088238  0.55472  0.01134  1.0205  ...  142.760  2.5568  3.2597      0
# 1 -0.006202  0.48465  0.23298  1.5998  ...  111.140  3.2841  3.3700      0
# 2  0.130240  0.22142  0.57751  3.6082  ...   71.531  5.1027  5.6188      0
# 3 -0.089951  0.88700  0.26927  1.5222  ...  147.560  2.4735  5.9299      0
# 4  0.048179  0.55041  0.10765  1.2437  ...  106.430  3.4294  3.3622      0
#
# [5 rows x 65 columns]

# %%
total_cells= np.product(d1.shape)
total_missing=d1.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
d1.describe()
# Out:
#              Attr1        Attr2  ...         Attr64        class
# count  5910.000000  5910.000000  ...    5910.000000  5910.000000
# mean     -0.022337     0.465141  ...      64.655742     0.069374
# std       6.162090     5.749823  ...    2131.113240     0.254110
# min    -463.890000  -430.870000  ...      -3.726500     0.000000
# 25%       0.003963     0.255370  ...       2.163200     0.000000
# 50%       0.046664     0.452020  ...       4.150500     0.000000
# 75%       0.117040     0.661530  ...       9.343575     0.000000
# max      87.459000    72.416000  ...  158180.000000     1.000000
#
# [8 rows x 65 columns]

# %% [markdown]
# ---

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# **There is imbalance in the Target value, we need to oversample it based**

# %% [markdown]
# # OverSamppling :SMOTE
#
# ---

# %%
from imblearn.over_sampling import SMOTE
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
sns.countplot(x=y)

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data 
data_x.shape
# Out:
#       Attr1    Attr2    Attr3   Attr4  ...  Attr61   Attr62  Attr63  Attr64
# 0  0.088238  0.55472  0.01134  1.0205  ...  4.7343  142.760  2.5568  3.2597
# 1 -0.006202  0.48465  0.23298  1.5998  ...  3.2749  111.140  3.2841  3.3700
# 2  0.130240  0.22142  0.57751  3.6082  ...  2.9870   71.531  5.1027  5.6188
# 3 -0.089951  0.88700  0.26927  1.5222  ...  3.3302  147.560  2.4735  5.9299
# 4  0.048179  0.55041  0.10765  1.2437  ...  4.0950  106.430  3.4294  3.3622
#
# [5 rows x 64 columns]
# (11000, 64)

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4  ...   Attr62  Attr63  Attr64  class
# 0  0.088238  0.55472  0.01134  1.0205  ...  142.760  2.5568  3.2597      0
# 1 -0.006202  0.48465  0.23298  1.5998  ...  111.140  3.2841  3.3700      0
# 2  0.130240  0.22142  0.57751  3.6082  ...   71.531  5.1027  5.6188      0
# 3 -0.089951  0.88700  0.26927  1.5222  ...  147.560  2.4735  5.9299      0
# 4  0.048179  0.55041  0.10765  1.2437  ...  106.430  3.4294  3.3622      0
#
# [5 rows x 65 columns]
